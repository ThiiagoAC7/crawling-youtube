# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/faculdade/coletor

# %%
# !python merge_datasets.py --youtubers mrbeast

# %%
# !ls -lh ./data/@mrbeast/
